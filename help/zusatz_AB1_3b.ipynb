# %% [markdown]
# Erweitere die zuvor implementierte Funktion um dein Alter. Deine Funktion nimmt nun also zwei Parameter (Name und Alter) entgegen und überprüft, ob diese mit deinem Namen und deinem Alter übereinstimmen. Ist einer der beiden Werte falsch, soll in jedem Fall "Das bin nicht ich" ausgegeben werden.
