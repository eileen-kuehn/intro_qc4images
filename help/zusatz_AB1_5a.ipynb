# %%
# Hier nichts ändern, nur ausführen!
import sys; sys.path.append("../code"); from setup_AB1 import *; setup_erfolg();

# %% [markdown]
# # Zusatzaufgabe für Aufgabe 5a) des Arbeitsblattes 1

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp;   </h2>
#     Erweitere deine Funktion so, dass sie auch die Länge des ersten Worts in der Liste ausgibt. Also z.B.: "Das ist eine lange Liste. Das erste Wort hat so viele Buchstaben: 10"
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp;   </h2>
#     Erweitere die obenstehende Funktion (<code>check_length</code>) so, das sie die Anzahl der Buchstaben jedes Eintrags der Liste bestimmt und den Mittelwert der Längen aller Einträge ausgibt (anstatt nur die Länge des ersten Wortes).
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp;   </h2>
#     Abschließend erweitere diese Funktion, so, dass sie die Wörter in der Liste durch die Anzahl der jeweiligen Buchstaben ersetzt und zurückgibt. Deine Funktion bekommt dann also eine Liste von Buchstaben und gibt eine Liste von Zahlen zurück. Nutze hierfür die Technik zum Abändern von Listen und verwende keine neue Liste.
# </div>
