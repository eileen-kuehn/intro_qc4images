# %%
# Hier nichts ändern, nur ausführen!
import sys; sys.path.append("../code"); from setup_AB2 import *; setup_erfolg();

# %% [markdown]
# # Zusatzaufgabe zur Aufgabe 3a) des Arbeitsblattes 2

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-puzzle-piece" style="font-size:36px"></i> &nbsp;   </h2>
#   <p>Nachdem wir die Katze bunt eingefärbt haben, lass uns doch nun mal abschließend versuchen, alle Farben in dem Bild zu invertieren. Hierfür müssen wir alle Werte im Bild vom Maximalwert (<code>255</code>) abziehen. Das bedeutet z.B. für ein Schwarzweißbild, dass Weiß zu Schwarz wird und umgekehrt. Bei mehreren Farbkanälen muss man das dann für jeden Kanal einzeln machen.</p>
#   <hr/>
#   <details>
#     <summary>Ein kleiner Tipp gefällig?</summary>
#     <ul>
#       <li>Beachte, dass du das für jeden einzelnen Kanal machen musst, das funktioniert z.B. über drei ineinander verschachtelte <code>for</code>-Schleifen</li>
#     </ul>
#   </details>
# </div>

# %%
# wir laden das Bild.
image = utils.load_image("../images/Kitten.jpg")

# Ab hier dein Code

image_copy = copy(image)

for row in range(
    image.shape[0]
):  # hier iterieren wir über alle Zeilen und nennen die aktuelle row
    for column in range(
        image.shape[1]
    ):  # hier über alle Spalten und nennen die aktuelle column
        # --- Ab hier dein Code ---

        # -------------------------
        pass

imshow(image_copy);
