# %%
# Hier nichts ändern, nur ausführen!
import sys; sys.path.append("../code"); from setup_AB2 import *; setup_erfolg();

# %% [markdown]
# # Arbeitsblatt 2 | Bildverarbeitung in Python
#
# Hier zeigen wir dir ein paar Grundlagen, wie man in **Python** mit Bildern arbeiten kann. Du lernst Bilder zu laden und zu bearbeiten.

# %% [markdown]
# # Bilderverarbeitung in Python
#
# In diesem Notebook bringen wir Dir ein paar Grundlagen bei, wie man in **Python** mit Bildern arbeiten kann. Du lernst Bilder zu laden und leicht zu bearbeiten. Damit weißt du dann auch schon alles, damit wir endlich mit Quantencomputern beginnen können.

# %% [markdown]
# <div id="information" class="alert alert-success">
#   <h2><i class="fas fa-info" style="font-size:36px"></i> </h2>
#     <p>Falls du bisher noch nicht programmiert hast, Python noch nicht kennst oder einfach nochmal etwas nachschlagen willst, schau dir gern die <a href="./Python_Basics.ipynb">Grundlagen zur Programmierung mit Python</a> an.</p>
# </div>

# %% [markdown]
# ## 1) Der Aufbau eines Bildes
#
# Wie Du wahrscheinlich weißt, sind Bilder aus ganz vielen **Pixeln** zusammengesetzt. Ein Pixel wiederum besteht bei einem Farbbild aus drei Werten: Rot, Grün, Blau - kurz: RGB. Bei einem Schwarz-Weiß-Bild besteht ein Pixel nur aus einem Wert. Aus wie vielen Werten ein Pixel besteht, wird auch als die Anzahl der **Farbkanäle** bezeichnet.
# Die Werte geben jeweils an, wie stark die Farbe in diesem Bild ist. Aber dazu gleich mehr.
#
# Ein Bild kann man sich somit als eine Art Tabelle vorstellen. Diese hat:
# - so viele Zeilen wie das Bild hoch ist (in Pixeln)
# - so viele Spalten wie das Bild breit ist (in Pixeln)
#
# In einer Tabellenposition stehen dann die Werte dieses Pixels an genau dieser Stelle. Bei einem Schwarz-Weiß-Bild steht da also ein Wert. Bei einem Farbbild drei Werte.
#
# Informatiker und Mathematiker nennen so eine Tabelle auch gerne **Matrix**. Auch in der Schule benutzt man die schon in den oberen Klassenstufen.

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> <br><br> a) Erstelle ein Schwarz-Weiß-Bild</h3>
#   <p>Fülle die nachfolgende Tabelle mit Werten zwischen 0 und 255 um ein Schwarz-Weiß-Bild zu erzeugen. Probiere ruhig unterschiedliche Zusammenstellungen aus.</p>
#   <hr/>
#   <p>Zusatzaufgabe:</p>
#   <ul>
#     <li>Färbe den Pixel in der linken unteren Ecke weiß.</li>
#   </ul>
# </div>

# %%
# Hier nichts ändern, nur ausführen!
show_image_table("AB2-1a")

# %%
# Hier nichts ändern, nur ausführen!
check_1a()

# %%
# Hier nichts ändern, nur ausführen!
show_bw_image("AB2-1a")

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> <br><br> a) Erstelle dein eigenes kleines Bild</h3>
#   <p>Erstelle ein eigenes kleines Bild, indem du die Pixelwerte zwischen 0 und 255 variierst.</p>
# </div>

# %%
# Hier nichts ändern, nur ausführen!
show_image_table("AB2-1b")

# %%
# Hier nichts ändern, nur ausführen!
show_bw_image("AB2-1b")

# %% [markdown]
# ## 2) Der Aufbau von Farbbildern
#
# Schwarz-Weiß-Bilder lassen sich noch sehr gut in solchen Matrizen bearbeiten. Bei "normalen" Bildern wird das allerdings schnell unübersichtlich. Diese bestehen meist aus Millionen von Werten. Für den Computer ist das kein Problem, der kann damit gut umgehen.
#
# Wir nutzen im Folgenden zur Arbeit mit Bildern sogenannte `arrays` aus dem Paket `numpy`.
#
# Arrays, Matrizen und Tabellen sind eigentlich genau das gleiche: immer eine Liste von Listen von Listen ...
# Die Anzahl der Verschachtelungen solch einer Liste nennt man seine **Dimension**.

# %% [markdown]
# <div id="information" class="alert alert-success">
#   <h2><i class="fas fa-info" style="font-size:36px"></i> </h2>
#   <p>Ein Schwarz-Weißbild hat die Dimension <code>2</code>. Warum gerade <code>2</code>? Intern kann die Tabelle oben als Liste von Listen gespeichert werden. Das sieht dann beispielsweise so aus:</p>
#
#   ```python
#   image = [[0, 0, 0], [0, 0, 0], [0, 255, 0], [0, 0, 0]]
#   ```
# </div>

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> <br><br> a) Dimension eines Farbbildes </h3>
#   <p>Überlege doch mal, welche Dimension ein Farbbild hat und notiere deine Gedanken dazu.</p>
# </div>

# %%
# Hier nichts ändern, nur ausführen!
prompt_2a()

# %% [markdown]
# Dann lass uns mal schauen, wieviele Dimensionen so ein Farbbild hat. Dazu laden wir zunächst das Bild der Katze aus dem Ordner `images` und zeigen dieses an.

# %%
image = load_image("../images/Kitten.jpg")
imshow(image);

# %% [markdown]
# An der Achsenbeschriftung kannst bereits sehen, wie groß dieses Bild in Pixeln ungefähr ist. Da das Bild als numpy `array` geladen wurde, gibt es aber auch die Möglichkeit `shape` zu benutzen, das uns die Größe für jede Dimension verrät. Ähnlich wie es `len()` für Listen tut. `shape` rufen wir  direkt auf der Liste mit einem Punkt getrennt auf.
#
# `shape` ist keine Funktion, sondern eine Eigenschaft, die das numpy `array` hat (Informatiker nennen das auch Attribut). Deswegen gibt es auch nicht, wie sonst bei Funktionen, runde Klammern.

# %%
print(image.shape)

print("Anzahl Zeilen:", image.shape[0])
print("Anzahl Spalten:", image.shape[1])
print("Anzahl Farbkanäle:", image.shape[2])

# %% [markdown]
# Wie du siehst, gibt `shape` auch eine Art Liste zurück. Mit den eckigen Klammern und einem Index können wir die einzelnen Elemente aufrufen.

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> <br><br> b) Anzahl einzelner Pixelwerte </h3>
#   <p>Bitte gib die Anzahl der Werte an, um diese kleine Katze darzustellen.</p>
#   <hr/>
#   <details>
#     <summary>Ein paar kleine Tipps gefällig?</summary>
#     <ul>
#       <li>Erstell dir gern eine eigene Code-Zeile, um eigene Berechnungen auszuführen.</li>
#       <li>Beachte, dass das Bild mehrere Farbkanäle (R, G und B) hat</li>
#     </ul>
#   </details>
# </div>

# %%
anzahl = None  # Gib hier die Anzahl der Werte ein

check_2b(anzahl)

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> <br><br> c) Auslesen einzelner Pixelwerte </h3>
#   <p>Bitte gib den Wert des Pixels in der 100. Zeile, 150. Spalte für den Rotkanal an.</p>
#   <hr/>
#   <p>Tipp: Bitte bedenke, dass Informatiker bei 0 zu zählen beginnen.</p>
# </div>

# %%
pixel = None

check_2c(pixel)

# %% [markdown]
# ## 3) Grundlagen der Bildverarbeitung
#
# Wir schauen uns nun ein paar Grundlagen der Bildverarbeitung, indem wir einzelne Pixelwerte verändern. Du kannst nämlich genau so, wie du eben Werte ausgelesen hast, auch Werte zuweisen.
#
# Wir setzen beispielhaft mal einen Pixel-Wert komplett auf rot. Also den R-Wert auf `255` und G und B jeweils auf `0`:

# %%
image[25, 200, 0] = 255
image[25, 200, 1] = 0
image[25, 200, 2] = 0

imshow(image);

# %% [markdown]
# Findest du den kleinen roten Punkt den wir gerade erzeugt haben?

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> <br><br> a) Einfärben des Bildes </h3>
#   <p>Bitte färbe nun das komplette Bild leicht rötlich ein.</p>
#   <hr/>
#   <p>Um das komplette Bild zu bearbeiten, kannst du am besten zwei <code>for</code>-Schleifen benutzen, die ineinander verschachtelt werden. Hier ist ein beispielhafter Code, den du verwenden kannst. <br/><br/>
#
#   ```python
#   for i in range(5):
#     for j in range(3):
#         print("i:", i, "  j: ", j)
#   ```
#
#   Wenn du dir unsicher bist, schaue gern in das <a href="./Python_Basics.ipynb">Notebook mit den Grundlagen zu Python</a>.</p>
#   <hr/>
#   <details>
#     <summary>Ein paar kleine Tipps gefällig?</summary>
#     <ul>
#       <li>Über <code>image.shape</code> bekommst du die Information, wieviele Zeilen und Spalten das Bild hat
#       <li>Erhöhe den Rot-wert für jeden Pixel um beispielsweise den Wert 100</li>
#       <li>Pass auf, dass keiner der Werte über <code>255</code> liegt</li>
#     </ul>
#   </details>
#   <hr/>
#   <a href="../help/tipps_AB2_3a.ipynb"><i class="fas fa-life-ring" style="font-size:20px"></i> &nbsp;Tipp</a> <span style="margin-right: 20px;"></span>   <!-- Link zum Tipp anpassen oder Zeile löschen-->
#   <a href="../help/zusatz_AB2_3a.ipynb"><i class="fas fa-puzzle-piece" style="font-size:20px"></i> &nbsp; Zusatzaufgabe</a>                                 <!-- Link zur Zusatzaufgabe anpassen oder Zeile löschen -->
# </div>

# %%
# Schreibe hier deine ineinander verschachtelten Schleifen
# damit durchläufst du alle Pixel des Bildes
# Erhöhe den Rot-Wert jedes Pixels, aber nicht über 255 hinaus

# Nun zeigen wir das Bild an
imshow(image);

# %% [markdown]
# <div id="information" class="alert alert-success">
#   <h2><i class="fas fa-info" style="font-size:36px"></i> </h2>
#   <p>Hat alles geklappt und du siehst eine rötliche Katze? Falls doch etwas schief gegangen ist oder du etwas anderes ausprobieren willst, kannst du das Bild auch neu laden:</p>
#   <code>image = load_image("../images/Kitten.jpg")</code>
# </div>

# %% [markdown]
# <hr>
#
# ## Zusammenfassung des zweiten Arbeitsblattes
#
# Auf dem zweiten Arbeitsblatt haben wir die Grundlagen der Bildbearbeitung mit Python kennengelernt. Wir haben dafür folgenden Themen bearbeitet:
#
# 1. **Aufbau eines Bildes:** Wir haben uns angeschaut, wie ein Schwarz-Weiß-Bild aufgebaut ist und wie das im Computer abgespeichert werden kann.
#
# 2. **Der Aufbau von Farbbildern:** Danach haben wir uns angeschaut, wie Farbbilder abgelegt werden und wie man das effizienter mit numpy arrays lösen kann.
#
# 3. **Grundlagen der Bildbearbeitung:** Zum Schluss haben wir uns noch angeschaut, wie Bilder eingefärbt werden können.
#
# <hr>
#
# ## Diskussion im Plenum <i class="fa fa-comments-o" style="font-size:36px"></i>
# **Wir werden die bisherigen Ergebnisse gemeinsam diskutieren!** <br>
# Nun geht es endlich los mit [den Grundlagen zur Arbeit mit Bildern auf dem Quantencomputer](./QolorQoding.ipynb).
#
# Wenn du nochmal etwas in den [Python Grundlagen](./Python_Basics.ipynb) nachschauen möchtest, kannst du das gern machen.
